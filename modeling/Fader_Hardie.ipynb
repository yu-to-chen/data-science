# %% [markdown]
# # BG/NBD
# This notebook was setup for a blog post on setting up the full bayesian model of Fader & Hardie (2011) to model customer repeat transactions. Check out the blog post here:
#
# https://sidravi1.github.io/blog/2018/07/08/fader-hardie-clv/

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from joblib import Parallel, delayed
from tqdm import tqdm_notebook as tqdm

data_dir = '/Users/ychen/Documents/results/research/clv/'
inline = 'clv'
mydate = '20211223'

# %% [markdown]
# ## Setup PYMC3 model

# %%
import pymc3 as pm
import numpy as np
import datetime

import theano.tensor as tt
from theano.ifelse import ifelse

# %%
# from: http://www.brucehardie.com/notes/004/
#data_bgn = pd.read_excel("bgnbd.xls", sheetname='Raw Data')
data_bgn = pd.read_csv("bgnbd.csv")

# %%
n_vals = len(data_bgn)
x = data_bgn['x'].values
t_x = data_bgn['t_x'].values
T = data_bgn['T'].values 

int_vec = np.vectorize(int)
x_zero = int_vec(x > 0)

# %%
with pm.Model() as model:
        
    a = pm.HalfCauchy('a',4)
    b = pm.HalfCauchy('b',4)
    
    alpha = pm.HalfCauchy('alpha',4)
    r = pm.HalfCauchy('beta',4)
    
    lam = pm.Gamma('lam', alpha, r, shape=n_vals)
    p = pm.Beta('p',a, b, shape=n_vals)
    
    # expected_all = pm.Deterministic('expected_all', (1/p)*(-tt.expm1(-lam * p * T)))
    
    def logp(x, t_x, T, x_zero):

        log_termA = tt.mul(x,tt.log(1-p)) + tt.mul(x,tt.log(lam)) - tt.mul(t_x,lam)

        termB_1 = tt.mul(-lam,(T - t_x))
        termB_2 = tt.log(p) - tt.log(1-p)
        
        log_termB = pm.math.switch(x_zero, pm.math.logaddexp(termB_1, termB_2), termB_1)
        
        return tt.sum(log_termA) + tt.sum(log_termB)
    
    like = pm.DensityDist('like', logp, observed = {'x':x, 't_x':t_x, 'T':T, 'x_zero':x_zero})

# %%
with model:
    #trace = pm.sample(draws=6000, target_accept = 0.95, tune=3000)
    trace = pm.sample(draws=6000, target_accept = 0.95, tune=3000, chains=2, cores=1)
    ##trace = pm.sample(n_draws, chains=1, cores=1, init=None)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [p, lam, beta, alpha, b, a]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9000' class='' max='9000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9000/9000 13:49<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9000' class='' max='9000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9000/9000 31:50<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 3_000 tune and 6_000 draw iterations (6_000 + 12_000 draws total) took 2740 seconds.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
_ = pm.traceplot(trace, varnames=['a','b','alpha','beta'])
# Out:
# /Users/ychen/Documents/projects/research/env3/lib/python3.7/site-packages/pymc3/plots/__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# /Users/ychen/Documents/projects/research/env3/lib/python3.7/site-packages/arviz/data/io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %% [markdown]
# ## Posteriors for hypers

# %%
a_post = trace['a']
b_post = trace['b']
alpha_post = trace['alpha']
#r_post = trace['r']
r_post = trace['beta']

# %%
plt.figure(figsize=(7,7))
ax = plt.subplot(221)
ax.hist(a_post, bins=50, density=True)
ax.set_title(r"posterior for $a$")
ax.axvline(0.793, ls="--", color='r', label="Fader-Hardie")
ax.legend()

ax = plt.subplot(222)
ax.hist(b_post, bins=50, density=True)
ax.set_title(r"posterior for $b$")
ax.axvline(2.426, ls="--", color='r', label="Fader-Hardie")
ax.legend()

ax = plt.subplot(223)
ax.hist(alpha_post, bins=50, density=True)
ax.set_title(r"posterior for $r$")
ax.axvline(0.243, ls="--", color='r', label="Fader-Hardie")
ax.legend()

ax = plt.subplot(224)
ax.hist(r_post, bins=50, density=True)
ax.set_title(r"posterior for $\alpha$")
ax.axvline(4.414, ls="--", color='r', label="Fader-Hardie")
ax.legend()

plt.tight_layout()
plt.savefig(data_dir + 'fader_posteriors_' + inline + '_' + mydate + '.png')

# %% [markdown]
# ## Model Checks

# %%
p_post = trace['p']
lam_post = trace['lam']

# %%
expected_all = (1/p_post)*(-np.expm1(-lam_post * p_post * T))

# %%
gr = pm.gelman_rubin(trace)

np.any(gr['expected_all'] > 1.01), np.any(gr['p'] > 1.01), np.any(gr['lam'] > 1.01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-6cc752fa823b> in <module>
# ----> 1 gr = pm.gelman_rubin(trace)
#       2
#       3 np.any(gr['expected_all'] > 1.01), np.any(gr['p'] > 1.01), np.any(gr['lam'] > 1.01)
#
# AttributeError: module 'pymc3' has no attribute 'gelman_rubin'

# %%
out = pm.geweke(trace, intervals=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-3a4c47cd6a12> in <module>
# ----> 1 out = pm.geweke(trace, intervals=10)
#
# ~/Documents/projects/research/env3/lib/python3.7/site-packages/pymc3/stats/__init__.py in wrapped(*args, **kwargs)
#      36                 )
#      37                 kwargs[new] = kwargs.pop(old)
# ---> 38             return func(*args, **kwargs)
#      39
#      40     return wrapped
#
# ~/Documents/projects/research/env3/lib/python3.7/site-packages/arviz/utils.py in __call__(self, *args, **kwargs)
#     183             return self.numba_fn(*args, **kwargs)
#     184         else:
# --> 185             return self.function(*args, **kwargs)
#     186
#     187
#
# ~/Documents/projects/research/env3/lib/python3.7/site-packages/arviz/stats/diagnostics.py in geweke(ary, first, last, intervals)
#     433     """
#     434     # Filter out invalid intervals
# --> 435     return _geweke(ary, first, last, intervals)
#     436
#     437
#
# ~/Documents/projects/research/env3/lib/python3.7/site-packages/arviz/stats/diagnostics.py in _geweke(ary, first, last, intervals)
#     462         last_slice = ary[int(end - last * (end - start)) :]
#     463
# --> 464         z_score = first_slice.mean() - last_slice.mean()
#     465         if _numba_flag:
#     466             z_score /= _sqrt(svar(first_slice), svar(last_slice))
#
# ~/Documents/projects/research/env3/lib/python3.7/site-packages/pymc3/backends/base.py in __getattr__(self, name)
#     366             return self.get_sampler_stats(name)
#     367         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 368             type(self).__name__, name))
#     369
#     370     def __len__(self):
#
# AttributeError: 'MultiTrace' object has no attribute 'mean'

# %%
out[1]['expected_all']
# Out:
# [array([[  0.00000000e+00,   8.95080360e-04],
#         [  3.33000000e+02,   1.52894892e-02],
#         [  6.66000000e+02,   3.10793757e-02],
#         [  9.99000000e+02,   3.10421241e-02],
#         [  1.33200000e+03,   3.64511443e-02],
#         [  1.66500000e+03,  -1.37252010e-02],
#         [  1.99800000e+03,   3.08666401e-02],
#         [  2.33100000e+03,  -3.89996788e-02],
#         [  2.66400000e+03,  -1.58229033e-02],
#         [  2.99700000e+03,  -1.19032942e-02]]),
#  array([[  0.00000000e+00,   7.05878554e-02],
#         [  3.33000000e+02,   2.18597084e-02],
#         [  6.66000000e+02,  -9.80355245e-02],
#         [  9.99000000e+02,  -7.66319576e-02],
#         [  1.33200000e+03,  -1.23958184e-02],
#         [  1.66500000e+03,  -8.11218047e-02],
#         [  1.99800000e+03,  -7.32895108e-04],
#         [  2.33100000e+03,  -5.20430856e-02],
#         [  2.66400000e+03,  -7.18538900e-02],
#         [  2.99700000e+03,  -9.15044977e-02]]),
#  array([[  0.00000000e+00,  -1.70076971e-02],
#         [  3.33000000e+02,   4.53033414e-02],
#         [  6.66000000e+02,   2.17887887e-02],
#         [  9.99000000e+02,  -2.15345291e-02],
#         [  1.33200000e+03,  -6.40358886e-02],
#         [  1.66500000e+03,  -5.52621014e-02],
#         [  1.99800000e+03,   2.98688739e-04],
#         [  2.33100000e+03,  -2.16668714e-02],
#         [  2.66400000e+03,  -3.64856378e-02],
#         [  2.99700000e+03,   2.91013499e-02]]),
#  array([[  0.00000000e+00,   4.76536725e-03],
#         [  3.33000000e+02,  -7.60690521e-03],
#         [  6.66000000e+02,   2.82875693e-03],
#         [  9.99000000e+02,   4.99238026e-02],
#         [  1.33200000e+03,  -9.38415034e-03],
#         [  1.66500000e+03,   3.53299832e-02],
#         [  1.99800000e+03,  -6.35605899e-03],
#         [  2.33100000e+03,   2.37324187e-02],
#         [  2.66400000e+03,   5.31733439e-02],
#         [  2.99700000e+03,  -1.00607270e-01]]),
#  array([[  0.00000000e+00,  -2.66708960e-04],
#         [  3.33000000e+02,   1.79895069e-03],
#         [  6.66000000e+02,  -1.18591706e-03],
#         [  9.99000000e+02,  -4.18056343e-03],
#         [  1.33200000e+03,   3.48787816e-02],
#         [  1.66500000e+03,   1.81284057e-02],
#         [  1.99800000e+03,   2.42258602e-02],
#         [  2.33100000e+03,   5.71335213e-04],
#         [  2.66400000e+03,   4.01903996e-02],
#         [  2.99700000e+03,  -7.24868758e-03]]),
#  array([[  0.00000000e+00,   1.27597804e-02],
#         [  3.33000000e+02,   1.39373067e-02],
#         [  6.66000000e+02,   3.87649432e-02],
#         [  9.99000000e+02,   7.06322253e-03],
#         [  1.33200000e+03,  -3.23146494e-02],
#         [  1.66500000e+03,   1.92473583e-02],
#         [  1.99800000e+03,  -2.59028881e-02],
#         [  2.33100000e+03,   5.93950027e-02],
#         [  2.99700000e+03,   4.87236673e-02]]),
#  array([[  0.00000000e+00,   4.42300097e-03],
#         [  3.33000000e+02,  -2.28528640e-02],
#         [  6.66000000e+02,  -5.44234395e-02],
#         [  9.99000000e+02,  -3.61337497e-02],
#         [  1.33200000e+03,  -5.41729523e-02],
#         [  1.66500000e+03,  -3.01295399e-02],
#         [  1.99800000e+03,   4.90271494e-02],
#         [  2.33100000e+03,  -1.14094601e-02],
#         [  2.66400000e+03,  -1.02315662e-02],
#         [  2.99700000e+03,   2.16690508e-02]]),
#  array([[  0.00000000e+00,   9.41947653e-03],
#         [  3.33000000e+02,   1.15259569e-03],
#         [  6.66000000e+02,  -9.71952907e-03],
#         [  9.99000000e+02,  -9.42198201e-03],
#         [  1.33200000e+03,  -6.63073512e-02],
#         [  1.66500000e+03,  -7.41440696e-02],
#         [  1.99800000e+03,   2.86182184e-02],
#         [  2.33100000e+03,   1.73175872e-02],
#         [  2.66400000e+03,   2.13298696e-02],
#         [  2.99700000e+03,   2.68302154e-02]]),
#  array([[  0.00000000e+00,  -3.32223474e-02],
#         [  3.33000000e+02,  -6.19647032e-02],
#         [  6.66000000e+02,  -4.91642468e-02],
#         [  9.99000000e+02,  -2.87898350e-02],
#         [  1.33200000e+03,  -3.87998396e-02],
#         [  1.66500000e+03,  -2.63013799e-02],
#         [  1.99800000e+03,  -1.84602401e-02],
#         [  2.33100000e+03,  -1.25066417e-02],
#         [  2.66400000e+03,   4.98255645e-02],
#         [  2.99700000e+03,   1.54546049e-02]]),
#  array([[  0.00000000e+00,  -1.64656543e-02],
#         [  3.33000000e+02,   2.12827436e-02],
#         [  6.66000000e+02,  -1.91374245e-02],
#         [  9.99000000e+02,  -2.46881205e-02],
#         [  1.33200000e+03,  -1.11962095e-02],
#         [  1.66500000e+03,  -3.91202510e-03],
#         [  1.99800000e+03,   2.09911985e-02],
#         [  2.33100000e+03,  -1.43842387e-03],
#         [  2.66400000e+03,  -5.61014642e-02],
#         [  2.99700000e+03,  -2.03731153e-02]]),
#  array([[  0.00000000e+00,  -2.06604165e-02],
#         [  3.33000000e+02,  -2.71873705e-03],
#         [  6.66000000e+02,   5.01228375e-03],
#         [  9.99000000e+02,  -7.30532855e-02],
#         [  1.33200000e+03,  -3.97249298e-02],
#         [  1.66500000e+03,   2.67037870e-02],
#         [  1.99800000e+03,   5.44016459e-03],
#         [  2.33100000e+03,  -3.04438075e-02],
#         [  2.66400000e+03,   3.18572109e-04],
#         [  2.99700000e+03,   7.47023237e-02]]),
#  array([[  0.00000000e+00,  -6.41890982e-03],
#         [  3.33000000e+02,  -4.20430334e-02],
#         [  6.66000000e+02,  -2.15940283e-02],
#         [  9.99000000e+02,  -4.52740307e-02],
#         [  1.33200000e+03,  -6.44163648e-02],
#         [  1.66500000e+03,   3.92949678e-02],
#         [  1.99800000e+03,  -1.12974840e-03],
#         [  2.33100000e+03,  -1.89932074e-02],
#         [  2.66400000e+03,  -1.80725073e-02],
#         [  2.99700000e+03,  -9.58889285e-02]]),
#  array([[  0.00000000e+00,   1.38667598e-02],
#         [  3.33000000e+02,   2.06082650e-02],
#         [  6.66000000e+02,   7.31771902e-03],
#         [  9.99000000e+02,   1.00325428e-03],
#         [  1.33200000e+03,   1.86855006e-02],
#         [  1.66500000e+03,   1.76631452e-02],
#         [  1.99800000e+03,   2.80675546e-02],
#         [  2.33100000e+03,   3.87185265e-03],
#         [  2.66400000e+03,  -3.77257064e-02],
#         [  2.99700000e+03,  -3.28637383e-03]]),
#  array([[  0.00000000e+00,  -2.00730343e-02],
#         [  3.33000000e+02,  -4.02388497e-02],
#         [  6.66000000e+02,  -7.14018764e-02],
#         [  9.99000000e+02,  -1.06111368e-01],
#         [  1.33200000e+03,  -1.63488447e-02],
#         [  1.66500000e+03,  -1.52796670e-02],
#         [  1.99800000e+03,  -2.07386082e-02],
#         [  2.33100000e+03,  -2.06141644e-02],
#         [  2.66400000e+03,   1.03770350e-02],
#         [  2.99700000e+03,   8.94954661e-02]]),
#  array([[  0.00000000e+00,  -5.60814928e-05],
#         [  3.33000000e+02,   1.60878263e-02],
#         [  6.66000000e+02,   9.38200806e-03],
#         [  9.99000000e+02,  -4.98263663e-03],
#         [  1.33200000e+03,  -2.58158055e-02],
#         [  1.66500000e+03,  -4.15183054e-02],
#         [  1.99800000e+03,   1.48038967e-02],
#         [  2.33100000e+03,  -1.01906930e-02],
#         [  2.66400000e+03,  -2.25103633e-02],
#         [  2.99700000e+03,   6.52925116e-03]]),
#  array([[  0.00000000e+00,  -7.71699952e-02],
#         [  3.33000000e+02,  -4.13777307e-02],
#         [  6.66000000e+02,  -4.02311183e-02],
#         [  9.99000000e+02,  -2.78218083e-02],
#         [  1.33200000e+03,  -1.85287311e-02],
#         [  1.66500000e+03,  -5.27387462e-03],
#         [  1.99800000e+03,  -1.55257256e-02],
#         [  2.33100000e+03,  -4.48806427e-02],
#         [  2.66400000e+03,  -1.05489504e-02],
#         [  2.99700000e+03,  -3.17417387e-02]]),
#  array([[  0.00000000e+00,  -1.05991954e-03],
#         [  3.33000000e+02,   1.57326988e-02],
#         [  6.66000000e+02,   8.70310806e-03],
#         [  9.99000000e+02,  -2.78721350e-03],
#         [  1.33200000e+03,  -2.66524513e-04],
#         [  1.66500000e+03,   2.49467353e-02],
#         [  1.99800000e+03,   1.78575358e-02],
#         [  2.33100000e+03,  -3.85263604e-02],
#         [  2.66400000e+03,   6.36228703e-03],
#         [  2.99700000e+03,   3.54208163e-02]]),
#  array([[  0.00000000e+00,   4.29730046e-02],
#         [  3.33000000e+02,   2.68680016e-02],
#         [  6.66000000e+02,  -1.03896387e-02],
#         [  9.99000000e+02,  -2.93105958e-02],
#         [  1.33200000e+03,  -1.64543321e-02],
#         [  1.66500000e+03,  -8.30750074e-03],
#         [  1.99800000e+03,  -2.19716934e-02],
#         [  2.33100000e+03,  -1.35125157e-02],
#         [  2.66400000e+03,   1.16063385e-02],
#         [  2.99700000e+03,  -4.82158770e-02]]),
#  array([[  0.00000000e+00,   8.34691225e-02],
#         [  3.33000000e+02,   8.22356653e-02],
#         [  6.66000000e+02,   2.30609335e-02],
#         [  9.99000000e+02,  -4.76384059e-02],
#         [  1.33200000e+03,   2.26513536e-02],
#         [  1.66500000e+03,  -2.09351348e-02],
#         [  1.99800000e+03,  -2.95417367e-02],
#         [  2.33100000e+03,  -9.95774506e-03],
#         [  2.66400000e+03,   6.45075946e-03],
#         [  2.99700000e+03,   3.91531591e-02]]),
#  array([[  0.00000000e+00,  -1.56483611e-02],
#         [  3.33000000e+02,   6.65109565e-03],
#         [  6.66000000e+02,   1.64717197e-02],
#         [  9.99000000e+02,  -4.40142456e-02],
#         [  1.33200000e+03,  -4.43730075e-02],
#         [  1.66500000e+03,  -4.24573393e-02],
#         [  1.99800000e+03,  -6.61191353e-02],
#         [  2.33100000e+03,  -5.28210868e-03],
#         [  2.66400000e+03,   4.89242459e-02],
#         [  2.99700000e+03,  -5.69652882e-03]]),
#  ...]

# %%
plt.scatter(*out[1]['a'].T)
plt.hlines([-1,1], 0, 3500, linestyles='dotted')
plt.xlim(0, 3500)
# Out:
# (0, 3500)

# %%
plt.scatter(*out[1]['b'].T)
plt.hlines([-1,1], 0, 3500, linestyles='dotted')
plt.xlim(0, 3500)
# Out:
# (0, 3500)

# %%
plt.scatter(*out[1]['alpha'].T)
plt.hlines([-1,1], 0, 3500, linestyles='dotted')
plt.xlim(0, 3500)
# Out:
# (0, 3500)

# %%
plt.scatter(*out[1]['beta'].T)
plt.hlines([-1,1], 0, 3500, linestyles='dotted')
plt.xlim(0, 3500)
# Out:
# (0, 3500)

# %% [markdown]
# ## Posterior Predictive Checks
# - The data points (the line) are in the high probability region of the distribution of E(X(t)|lambda, p).

# %%
# pick some random idx

idx = np.random.choice(np.arange(len(x)), size=16, replace=False)
f, axes = plt.subplots(4,4, figsize=(10,10))

for ax, i in zip(axes.ravel(), idx):
    _ = ax.hist(expected_all[:,i], density=True, alpha = 0.7, bins=20)
    _ = ax.axvline(x[i],ls='--', color='firebrick')
    _ = ax.set_title('cust: {numb}'.format(numb=i))
_ = plt.tight_layout()

plt.savefig(data_dir + 'fader_ppc_' + inline + '_' + mydate + '.png')

# %% [markdown]
# ## Testing out ADVI

# %%
with model:
    inference = pm.ADVI()
    approx = pm.fit(n=30000, method=inference)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='30000' class='' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [30000/30000 00:31<00:00 Average Loss = 10,266]
#     </div>
# Finished [100%]: Average Loss = 10,266

# %%
plt.plot(-inference.hist, label='ADVI', alpha=.3)
plt.legend()
plt.ylabel('ELBO')
plt.xlabel('iteration');

# %%
trace_approx = approx.sample(draws=12000)

# %%
p = trace_approx.get_values('p', chains=0)
lam = trace_approx.get_values('lam', chains=0)

expected_all_approx = (1/p)*(-np.expm1(-lam * p * T))

# %% [markdown]
# ### How does the approximation compare?

# %%
idx = np.random.choice(np.arange(len(x)), size=16, replace=False)
f, axes = plt.subplots(4,4, figsize=(10,10))

for ax, i in zip(axes.ravel(), idx):
    _ = sns.kdeplot(expected_all_approx[:,i], alpha = 0.7, label='ADVI', ax=ax)
    _ = sns.kdeplot(expected_all[:,i], alpha = 0.7, label='MCMC', ax=ax)
_ = plt.tight_layout()
